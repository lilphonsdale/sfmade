# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
solm_results = pd.read_excel("Data/2021_SJ.xlsx", header=[0,1])
solm_results
# Out:
#         Respondent ID       Collector ID          Start Date  \
#    Unnamed: 0_level_1 Unnamed: 1_level_1  Unnamed: 2_level_1
# 0         13309104683          414221110 2022-02-04 15:50:20
# 1         13284562190          414221110 2022-01-25 12:41:30
# 2         13342052617          414221110 2022-02-18 10:52:18
# 3         13335910796          414221110 2022-02-16 09:36:13
# 4         13335908064          414221110 2022-02-16 09:35:08
# 5         13333904781          414221110 2022-02-15 16:12:00
# 6         13290875942          414221110 2022-01-27 15:16:49
# 7         13323635896          414221110 2022-02-10 21:52:39
# 8         13319640187          414221110 2022-02-09 11:49:41
# 9         13311945338          414221110 2022-02-06 18:44:35
# 10        13308460036          414221110 2022-02-04 10:33:51
# 11        13308344612          414221110 2022-02-04 09:44:39
# 12        13306083046          414221110 2022-02-03 12:19:29
# ...

# %%
for col in solm_results.columns:
    print(col)
# Out:
# ('Respondent ID', 'Unnamed: 0_level_1')
# ('Collector ID', 'Unnamed: 1_level_1')
# ('Start Date', 'Unnamed: 2_level_1')
# ('End Date', 'Unnamed: 3_level_1')
# ('IP Address', 'Unnamed: 4_level_1')
# ('Email Address', 'Unnamed: 5_level_1')
# ('First Name', 'Unnamed: 6_level_1')
# ('Last Name', 'Unnamed: 7_level_1')
# ('Custom Data 1', 'Unnamed: 8_level_1')
# ('Contact Information', 'Name:')
# ('Contact Information', 'Title/Position:')
# ('Contact Information', 'Company:')
# ('Contact Information', 'Primary Company Address:')
# ('Contact Information', 'City/Town:')
# ('Contact Information', 'State:')
# ('Contact Information', 'Zip Code:')
# ('Contact Information', 'Country:')
# ('Contact Information', 'Email Address:')
# ('Contact Information', 'Phone Number:')
# ('Estimate 2021 Revenue', '$0 - $250,000')
# ('Estimate 2021 Revenue', '$250,000 - $500,000')
# ('Estimate 2021 Revenue', '$500,000 - $750,000')
# ('Estimate 2021 Revenue', '$750,000 - $1M')
# ...

# %%
for i in solm_results.columns:
    plt.figure()
    plt.hist(solm_results[i])
# Out:
# /Users/phillonsdale/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:6607: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# /Users/phillonsdale/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:6608: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/f7/nskb_8916130461bmsfyq0y40000gn/T/ipykernel_21278/2310222959.py in <module>
#       1 for i in solm_results.columns:
#       2     plt.figure()
# ----> 3     plt.hist(solm_results[i])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2600         orientation='vertical', rwidth=None, log=False, color=None,
# ...

# %%
solm_results['Where is your manufacturing done? (Estimate % based on product value.)', '% In-House: San Jose'].value_counts()
# Out:
# 100.0    17
# 50.0      3
# 90.0      3
# 85.0      2
# 30.0      1
# 75.0      1
# 0.0       1
# 70.0      1
# 98.0      1
# 20.0      1
# 80.0      1
# Name: (Where is your manufacturing done? (Estimate % based on product value.), % In-House: San Jose), dtype: int64

# %%
plt.figure()
plt.scatter(solm_results['Where is your manufacturing done? (Estimate % based on product value.)', '% In-House: San Jose'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/f7/nskb_8916130461bmsfyq0y40000gn/T/ipykernel_21278/1034295784.py in <module>
#       1 plt.figure()
# ----> 2 plt.scatter(solm_results['Where is your manufacturing done? (Estimate % based on product value.)', '% In-House: San Jose'])
#
# TypeError: scatter() missing 1 required positional argument: 'y'

# %%
# https://cmdlinetips.com/2019/11/how-to-highlight-data-points-with-colors-and-text-in-python/#:~:text=Matplotlib%20has%20a%20function%20named,the%20location%20of%20the%20text.
